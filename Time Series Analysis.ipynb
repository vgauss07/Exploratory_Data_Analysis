# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
shampoo = pd.read_csv('/Users/vokeojuederhie/PycharmProjects/untitled6/shampoo_with_exog.csv')

# %%
shampoo.head()
shampoo = pd.read_csv('shampoo_with_exog.csv',index_col=[0],parse_dates=True,squeeze=True)

# %%
type(shampoo)
# Out:
# pandas.core.frame.DataFrame

# %%
shampoo.plot()
shampoo.plot(style = 'k.')

# %%
shampoo.size
del shampoo['Inflation']

# %%
shampoo
# Out:
#         Sales
# Month
# 1-Jan   266.0
# 2-Jan   145.9
# 3-Jan   183.1
# 4-Jan   119.3
# 5-Jan   180.3
# 6-Jan   168.5
# 7-Jan   231.8
# 8-Jan   224.5
# 9-Jan   192.8
# 10-Jan  122.9
# 11-Jan  336.5
# 12-Jan  185.9
# 1-Feb   194.3
# 2-Feb   149.5
# 3-Feb   210.1
# 4-Feb   273.3
# 5-Feb   191.4
# 6-Feb   287.0
# 7-Feb   226.0
# 8-Feb   303.6
# 9-Feb   289.9
# 10-Feb  421.6
# 11-Feb  264.5
# 12-Feb  342.3
# 1-Mar   339.7
# 2-Mar   440.4
# 3-Mar   315.9
# 4-Mar   439.3
# 5-Mar   401.3
# 6-Mar   437.4
# 7-Mar   575.5
# 8-Mar   407.6
# 9-Mar   682.0
# 10-Mar  475.3
# 11-Mar  581.3
# 12-Mar  646.9

# %%
shampoo.head()
shampoo.plot()
shampoo.plot(style = 'k.')

# %%
shampoo.describe()
# Out:
#             Sales
# count   36.000000
# mean   312.600000
# std    148.937164
# min    119.300000
# 25%    192.450000
# 50%    280.150000
# 75%    411.100000
# max    682.000000

# %%
shampoo_ma = shampoo.rolling(window=10).mean()
shampoo_ma.plot()
